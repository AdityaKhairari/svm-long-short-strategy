# %%
import pandas as pd
import numpy as np

# %%
import yfinance as yf

# %%
# !python3 -m pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/AdityaKhairari/Desktop/svm-long-short-strategy/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
df = pd.read_csv("financials.csv")
df
# Out:
#    symbol                          name                            sector  \
# 0     AFL                         Aflac           Life & Health Insurance
# 1     ALL                      Allstate     Property & Casualty Insurance
# 2     AXP              American Express                  Consumer Finance
# 3     AIG  American International Group     Property & Casualty Insurance
# 4     AMP          Ameriprise Financial  Asset Management & Custody Banks
# ..    ...                           ...                               ...
# 61    TFC                        Truist                    Regional Banks
# 62    USB                     U.S. Bank                 Diversified Banks
# 63    WFC                   Wells Fargo                 Diversified Banks
# 64    WTW          Willis Towers Watson                 Insurance Brokers
# 65   ZION          Zions Bancorporation                    Regional Banks
#
#                          location    year  month  date      CIK  year_started
# ...

# %%
ticker_list = " ".join(list(df.symbol))
ticker_list
# Out:
# 'AFL ALL AXP AIG AMP AON AJG AIZ BAC WRB BRK-B BLK BK BRO COF CBOE SCHW CB CINF C CFG CME CMA DFS RE FDS FITB FRC BEN GL GS HIG HBAN ICE IVZ JPM KEY LNC L MTB MKTX MMC MET MCO MS MSCI NDAQ NTRS PNC PFG PGR PRU RJF RF SPGI SBNY STT SIVB SYF TROW TRV TFC USB WFC WTW ZION'

# %%
financials = yf.Tickers(ticker_list)

# %%
dir(financials)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'download',
#  'history',
#  'news',
#  'symbols',
#  'tickers']

# %%
data = financials.history(period="2y")
data
# Out:
# [*********************100%***********************]  66 of 66 completed
#                 Close                                                 \
#                   AFL        AIG         AIZ         AJG         ALL
# Date
# 2020-09-02  35.073437  28.221478  119.802811  104.094414   89.825760
# 2020-09-03  35.111458  27.814663  117.851494  101.835312   88.638710
# 2020-09-04  35.985916  28.193094  118.498711  100.958931   89.085037
# 2020-09-08  35.111458  27.332163  116.218956   98.427155   86.653976
# 2020-09-09  35.206509  27.578146  117.223610  100.520737   87.879013
# ...               ...        ...         ...         ...         ...
# 2022-08-29  60.820000  52.799999  161.050003  184.540207  123.239998
# 2022-08-30  60.130001  52.389999  158.169998  182.376297  122.339996
# 2022-08-31  59.419998  51.750000  158.490005  181.060013  120.500000
# 2022-09-01  59.520000  52.340000  160.000000  181.600006  121.389999
# ...

# %%
print(data.columns)
# Out:
# MultiIndex([( 'Close',  'AFL'),
#             ( 'Close',  'AIG'),
#             ( 'Close',  'AIZ'),
#             ( 'Close',  'AJG'),
#             ( 'Close',  'ALL'),
#             ( 'Close',  'AMP'),
#             ( 'Close',  'AON'),
#             ( 'Close',  'AXP'),
#             ( 'Close',  'BAC'),
#             ( 'Close',  'BEN'),
#             ...
#             ('Volume',  'STT'),
#             ('Volume',  'SYF'),
#             ('Volume',  'TFC'),
#             ('Volume', 'TROW'),
#             ('Volume',  'TRV'),
#             ('Volume',  'USB'),
#             ('Volume',  'WFC'),
#             ('Volume',  'WRB'),
#             ('Volume',  'WTW'),
#             ('Volume', 'ZION')],
#            length=462)

# %%
data['Close']['AFL']
# Out:
# Date
# 2020-09-02    35.073437
# 2020-09-03    35.111458
# 2020-09-04    35.985916
# 2020-09-08    35.111458
# 2020-09-09    35.206509
#                 ...
# 2022-08-29    60.820000
# 2022-08-30    60.130001
# 2022-08-31    59.419998
# 2022-09-01    59.520000
# 2022-09-02    60.310001
# Name: AFL, Length: 505, dtype: float64

# %%
def percent_change(arr, n_days):
    change = []
    for i in range(n_days):
        change.append((arr[i]/arr[0]) - 1)
    for i in range(n_days, len(arr)):
        change.append((arr[i]/arr[i-n_days]) - 1)
        
    return change

# %%
def moving_average(arr, n_days):
    ma = []
    buff = 0
    for i in range(n_days):
        buff += arr[i]
        ma.append(buff/i)
    for i in range(n_days, len(arr)):
        buff += arr[i]
        buff -= arr[i-n_days]
        ma.append(buff/n_days)
        
    return obv

# %%
def price_volume(open_arr, close_arr, volume_arr):
    pv = []
    for i in range(len(volume_arr)):
        pv.append((close_arr[i] - open_arr[i]) * volume_arr[i])
        
    return pv

# %%
def obv(price_volume_arr, n_days):
    obv = []
    obv_buff = 0
    
    for i in range(n_days):
        obv_buff += price_volume_arr[i]
        obv.append(obv_buff)
    for i in range(n_days, len(arr)):
        obv_buff += price_volume_arr[i]
        obv_buff -= price_volume_arr[i - n_days]
        obv.append(obv_buff)
        
    return obv

# %%
RIL = yf.Ticker("BRK-A")
RIL.history()
# Out:
#                 Open          High          Low     Close  Volume  Dividends  \
# Date
# 2022-08-02  445734.0  445734.00000  438650.0000  439180.0    2300          0
# 2022-08-03  443964.0  444851.00000  437005.0000  443450.0    2600          0
# 2022-08-04  444294.0  445200.00000  440875.0000  442149.0    2600          0
# 2022-08-05  438635.0  443384.00000  436510.0000  439529.0    2300          0
# 2022-08-08  445259.0  450000.00000  439010.0000  439167.0    3100          0
# 2022-08-09  441378.0  447370.00000  438665.0000  440058.0    2200          0
# 2022-08-10  445300.0  446904.00000  441500.0000  442800.0    2300          0
# 2022-08-11  448839.0  448869.00000  444701.0000  445302.0    2300          0
# 2022-08-12  448193.0  453059.00000  446132.0000  452697.0    2400          0
# 2022-08-15  450929.0  456992.00000  446866.0000  455170.0    3100          0
# 2022-08-16  459224.0  463000.00000  456000.0000  461300.0    2700          0
# ...
